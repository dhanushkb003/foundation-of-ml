# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df=pd.read_csv("pima.csv")

# %%
df.head()
# Out:
#    preg  plas  pres  skin   test  mass   pedi  age  class
# 0     6   148    72    35      0  33.6  0.627   50      1
# 1     1    85    66    29      0  26.6  0.351   31      0
# 2     8   183    64     0      0  23.3  0.672   32      1
# 3     1    89    66    23     94  28.1  0.167   21      0
# 4     0   137    40    35    168  43.1  2.288   33      1

# %%
df.tail()
# Out:
#      preg  plas  pres  skin   test  mass   pedi  age  class
# 763    10   101    76    48    180  32.9  0.171   63      0
# 764     2   122    70    27      0  36.8  0.340   27      0
# 765     5   121    72    23    112  26.2  0.245   30      0
# 766     1   126    60     0      0  30.1  0.349   47      1
# 767     1    93    70    31      0  30.4  0.315   23      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   preg    768 non-null    int64
#  1   plas    768 non-null    int64
#  2   pres    768 non-null    int64
#  3   skin    768 non-null    int64
#  4    test   768 non-null    int64
#  5   mass    768 non-null    float64
#  6   pedi    768 non-null    float64
#  7   age     768 non-null    int64
#  8   class   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.columns
# Out:
# Index(['preg', 'plas', 'pres', 'skin', ' test', 'mass', 'pedi', 'age',
#        'class'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# preg     0
# plas     0
# pres     0
# skin     0
#  test    0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
dupes=df.duplicated()

# %%
dupes.sum()
# Out:
# np.int64(0)

# %% [markdown]
# Exploratory Data Analysis

# %%
df.groupby(['class']).value_counts(normalize=True)
# Out:
# class  preg  plas  pres  skin   test  mass  pedi   age
# 0      0     57    60    0     0      21.7  0.735  67     0.002000
#              67    76    0     0      45.3  0.194  46     0.002000
#              73    0     0     0      21.1  0.342  25     0.002000
#              74    52    10    36     27.8  0.269  22     0.002000
#              78    88    29    40     36.9  0.434  21     0.002000
#                                                             ...
# 1      13    158   114   0     0      42.3  0.257  44     0.003731
#        14    100   78    25    184    36.6  0.412  46     0.003731
#              175   62    30    0      33.6  0.212  38     0.003731
#        15    136   70    32    110    37.1  0.153  43     0.003731
#        17    163   72    41    114    40.9  0.817  47     0.003731
# Name: proportion, Length: 768, dtype: float64

# %%
df['class'].value_counts(normalize=True)
# Out:
# class
# 0    0.651042
# 1    0.348958
# Name: proportion, dtype: float64

# %%
df['class'].value_counts()
# Out:
# class
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# Univariate analysis

# %%
sns.histplot(df['plas'])
# Out:
# <Axes: xlabel='plas', ylabel='Count'>

# %%
sns.boxplot(df['plas'])
# Out:
# <Axes: ylabel='plas'>

# %%
sns.distplot(df['skin'])
# Out:
# C:\Users\DHANUSH\AppData\Local\Temp\ipykernel_29460\4096682644.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['skin'])
# <Axes: xlabel='skin', ylabel='Density'>

# %%
ax = sns.countplot(x='preg', data=df, palette="tab10")
# Add count labels on top of bars
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\DHANUSH\AppData\Local\Temp\ipykernel_29460\1884718668.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='preg', data=df, palette="tab10")

# %% [markdown]
# Bivariate analysis

# %%
sns.boxplot(df['mass'])
# Out:
# <Axes: ylabel='mass'>

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='class', y='mass', data=df, color= 'Black',palette=['blue', 'orange'])
plt.show()
# Out:
# C:\Users\DHANUSH\AppData\Local\Temp\ipykernel_29460\3907387990.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='mass', data=df, color= 'Black',palette=['blue', 'orange'])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x = 'class', y = 'age', data=df, palette=['Black','green'])
plt.show()
# Out:
# C:\Users\DHANUSH\AppData\Local\Temp\ipykernel_29460\513402702.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'class', y = 'age', data=df, palette=['Black','green'])

# %% [markdown]
# Both Categorical data-Pivot table

# %%
b=pd.crosstab(df['preg'], df['class']).plot(kind='bar')
for container in b.containers:
    b.bar_label(container)

plt.show()

pd.crosstab(df['preg'], df['class']).plot(kind='bar')

#pd.crosstab(df.no_older_children,df.Holliday_Package).plot(kind='bar')
# Out:
# <Axes: xlabel='preg'>

# %% [markdown]
# pairplot

# %%
sns.pairplot(df, hue="class",diag_kind = 'kde')

# %%
df.boxplot(vert=0)
# Out:
# <Axes: >

# %% [markdown]
# Remove outlier

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for column in df.columns:
    lr,ur=remove_outlier(df[column])
    df[column]=np.where(df[column]>ur,ur,df[column])
    df[column]=np.where(df[column]<lr,lr,df[column])

# %%
df.boxplot(vert=0)
# Out:
# C:\Users\DHANUSH\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(labels, **kwargs)
# <Axes: >

# %% [markdown]
# Model Building

# %%
X = df.drop('class', axis=1)
y=df.pop('class')

# %%
X
# Out:
#      preg   plas  pres  skin   test  mass   pedi   age
# 0     6.0  148.0  72.0  35.0    0.0  33.6  0.627  50.0
# 1     1.0   85.0  66.0  29.0    0.0  26.6  0.351  31.0
# 2     8.0  183.0  64.0   0.0    0.0  23.3  0.672  32.0
# 3     1.0   89.0  66.0  23.0   94.0  28.1  0.167  21.0
# 4     0.0  137.0  40.0  35.0  168.0  43.1  1.200  33.0
# ..    ...    ...   ...   ...    ...   ...    ...   ...
# 763  10.0  101.0  76.0  48.0  180.0  32.9  0.171  63.0
# 764   2.0  122.0  70.0  27.0    0.0  36.8  0.340  27.0
# 765   5.0  121.0  72.0  23.0  112.0  26.2  0.245  30.0
# 766   1.0  126.0  60.0   0.0    0.0  30.1  0.349  47.0
# 767   1.0   93.0  70.0  31.0    0.0  30.4  0.315  23.0
#
# [768 rows x 8 columns]

# %%
y
# Out:
# 0      1.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      1.0
#       ...
# 763    0.0
# 764    0.0
# 765    0.0
# 766    1.0
# 767    0.0
# Name: class, Length: 768, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size= 0.30, random_state= 1)
X_train
# Out:
#      preg   plas  pres  skin     test  mass   pedi   age
# 88   13.5  136.0  70.0  32.0  110.000  37.1  0.153  43.0
# 467   0.0   97.0  64.0  36.0  100.000  36.8  0.600  25.0
# 550   1.0  116.0  70.0  28.0    0.000  27.4  0.204  21.0
# 147   2.0  106.0  64.0  35.0  119.000  30.5  1.200  34.0
# 481   0.0  123.0  88.0  37.0    0.000  35.2  0.197  29.0
# ..    ...    ...   ...   ...      ...   ...    ...   ...
# 645   2.0  157.0  74.0  35.0  318.125  39.4  0.134  30.0
# 715   7.0  187.0  50.0  33.0  318.125  33.9  0.826  34.0
# 72   13.0  126.0  90.0   0.0    0.000  43.4  0.583  42.0
# 235   4.0  171.0  72.0   0.0    0.000  43.6  0.479  26.0
# 37    9.0  102.0  76.0  37.0    0.000  32.9  0.665  46.0
#
# [537 rows x 8 columns]

# %%
X_test
# Out:
#      preg   plas  pres  skin   test  mass   pedi   age
# 285   7.0  136.0  74.0  26.0  135.0  26.0  0.647  51.0
# 101   1.0  151.0  60.0   0.0    0.0  26.1  0.179  22.0
# 581   6.0  109.0  60.0  27.0    0.0  25.0  0.206  27.0
# 352   3.0   61.0  82.0  28.0    0.0  34.4  0.243  46.0
# 726   1.0  116.0  78.0  29.0  180.0  36.1  0.496  25.0
# ..    ...    ...   ...   ...    ...   ...    ...   ...
# 241   4.0   91.0  70.0  32.0   88.0  33.1  0.446  22.0
# 599   1.0  109.0  38.0  18.0  120.0  23.1  0.407  26.0
# 650   1.0   91.0  54.0  25.0  100.0  25.2  0.234  23.0
# 11   10.0  168.0  74.0   0.0    0.0  38.0  0.537  34.0
# 214   9.0  112.0  82.0  32.0  175.0  34.2  0.260  36.0
#
# [231 rows x 8 columns]

# %%
y_train
# Out:
# 88     1.0
# 467    0.0
# 550    0.0
# 147    0.0
# 481    0.0
#       ...
# 645    0.0
# 715    1.0
# 72     1.0
# 235    1.0
# 37     1.0
# Name: class, Length: 537, dtype: float64

# %%
y_test
# Out:
# 285    0.0
# 101    0.0
# 581    0.0
# 352    0.0
# 726    0.0
#       ...
# 241    0.0
# 599    0.0
# 650    0.0
# 11     1.0
# 214    1.0
# Name: class, Length: 231, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
lrmodel=LogisticRegression()
lrmodel.fit(X_train, y_train)
# Out:
# C:\Users\DHANUSH\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lrmodel.score(X_train, y_train)
# Out:
# 0.776536312849162

# %%
lrmodel.score(X_test, y_test)
# Out:
# 0.7922077922077922

# %%
print(lrmodel.intercept_)
# Out:
# [-8.04305504]

# %%
lrmodel.coef_
# Out:
# array([[ 1.03413324e-01,  3.30041675e-02, -1.87330941e-02,
#         -5.35033886e-03, -9.38401881e-04,  1.00119830e-01,
#          1.16442614e+00,  1.57553993e-02]])

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, lrmodel.coef_[0][idx]))
# Out:
# The coefficient for preg is 0.10341332449467425
# The coefficient for plas is 0.033004167500628005
# The coefficient for pres is -0.018733094140795863
# The coefficient for skin is -0.005350338863072543
# The coefficient for  test is -0.000938401881100443
# The coefficient for mass is 0.10011983003525113
# The coefficient for pedi is 1.164426144377394
# The coefficient for age is 0.01575539926795614

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_train_predict = lrmodel.predict(X_train)

# %%
confusion_matrix(y_train, y_train_predict)
# Out:
# array([[315,  39],
#        [ 81, 102]])

# %%
print(classification_report(
    y_train, y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.89      0.84       354
#          1.0       0.72      0.56      0.63       183
#
#     accuracy                           0.78       537
#    macro avg       0.76      0.72      0.73       537
# weighted avg       0.77      0.78      0.77       537

# %% [markdown]
# AUC & ROC curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
#ROC AND AUC
y_train_predict=lrmodel.predict(X_train)
y_train_predict_prob=lrmodel.predict_proba(X_train)[:,1]
roc_auc = roc_auc_score(y_train, y_train_predict_prob)

# %%
y_train_predict_prob = lrmodel.predict_proba(X_train)[:,1]

# %%
roc_auc = roc_auc_score (y_train, y_train_predict_prob)

# %%
roc_auc
# Out:
# 0.8303078015498132

# %%
fpr, tpr, thresholds = roc_curve( y_train, y_train_predict_prob)

# %%
fpr, tpr, thresholds = roc_curve(y_train, y_train_predict_prob)

# %%
plt.plot([0,1], [0,1], linestyle= '--' )
plt.plot(fpr, tpr)

# %% [markdown]
# The end
